# %%
'''Task 1: Increment Salary
Take input from user, take input square and divide by 10'''

Name = input("Enter your name:")
Salary = int(input("Enter your salary:"))
Num=10
FianlSalary =(Salary ** 2)/(Num)

print("Hello {}, Your Incremented salary is {}".format(Name,FianlSalary))

# %%
'''Task 2:
    Main input string :PYTHON prograMing Language IS use for AI model I develoPMent and DaTA Engineering data Pipeline

    Input Substring: " ,Data Analysis and
    
    User provide feedbakc in single line
    1.reapet words count
    2.first 3 words upper,lower 
    3.sub string with final string
    4.repeated count final string end count + word"'''

Main_string ="PYTHON prograMing Language IS use for AI model I develoPMent and DaTA Engineering data Pipeline"

Input_substring: " ,Data Analysis and"

#first 3 words upper,lower 

str1=Main_string.upper()[0:3]
str2= Main_string.lower()[3:]
str3 =str1 + str2
print(str3)
#PYThon programing language is use for ai model i development and data engineering pipeline

#sub string with final string
sub_string = str3.replace ("and"," ,Data Analysis and")
print(sub_string)
str4= sub_string.split()
print(str4)
#['PYThon', 'programing', 'language', 'is', 'use', 'for', 'ai', 'model', 'i', 'development', ',Data', 'Analysis', 'and', 'data', 'engineering', 'data', 'pipeline']

#reapet words count
str5=str4.count("data")
print(str5)

#repeated count final string end count + word"'''

Final_str= str3 + ' ' + str(str5 ) + ' ' + "data"
print(Final_str)
